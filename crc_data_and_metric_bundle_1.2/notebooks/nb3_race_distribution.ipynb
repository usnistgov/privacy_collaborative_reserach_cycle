# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Authors:
# - [Karan Bhagat](mailto:kb.in.triangulum@gmail.com) - Developer
# - [Christine Task](mailto:christine.task@knexusresearch.com) - Project technical lead
# - [Dhruv Kapur](mailto:dhruvka@umich.edu) - Contributor

# %% [markdown]
# ## NIST Collaborative Research Cycle (CRC)
# ### Example Notebook 3: Race Distribution (difference in count of records of each race in deid dataset and target dataset).
#
# One concern with data deidentification is the difficulty of maintaining accurate data distributions on data with diverse subpopulations. Privacy algorithms tend to reduce the visibility of outliers-- either intentionally, through Statistical Disclosure Limitation suppression schemes such as k-anonymity, or indirectly, through additive noise that has a relatively bigger impact on small counts (ie, a count of 2 +/- 2 retains less information than a count of 200 +/- 2).  When a diverse subpopulation has a smaller number of individuals, and those individuals have feature combinations that differ from the majority, that group can be dispersed more thinly across the feature space and then become significantly altered or erased during deidentification.
#
# In this notebook we show how to check in on this potential problem for our deidentified data samples, using a simple metric that compares the edit distance between the race distribution in the target data and deidentified data (using the csv data files for each). At the end of the notebook we print a data frame containing this metric and other algorithm properties that may be worthy of further exploration.
#
# #### List of topics covered in this notebook:
# 0. [Setup notebook.](#nb3-section-0)
# 1. [Load deid datasets index file (index.csv).](#nb3-section-1)
# <!--    1.1 [List properties (columns) of each deid. dataset (each row) in the index dataframe (created from index.csv).](#section-1.1)  -->
# 2. [CCompute difference in densities of each race between deid and target datasets.](#nb3-section-2)

# %% [markdown]
# <a id="nb3-section-0"></a>
# ## Setup notebook.

# %% [markdown]
# ### Import required libraries

# %%
# import required libraries
from pathlib import Path  # for creating paths for the filesystem operations
import os  # for filesystem operations
import pandas as pd  # for tabular data operations
import numpy as np  # for tabular data operations
import matplotlib.pyplot as plt  # for plotting data as charts
import json

# %% [markdown]
# ### Import local libraries present in libs package

# %%
# Import helper constants and functions
# libs.util has some small utility functions
# such has read_json, list_report etc.
import libs.util as u
# libs.plot module contains some helper
# funtions to create matplotlib charts
import libs.plot as plot
# libs.strs contains some constant strings
# represeting columns/feature names in index.csv file,
# report.json file, etc.
# Some examples of such constants: 
# LIBRARY_NAME, ALOGIRTHM_NAME, TARGET_DATASETetc.
from libs.strs import *
# lib.strs provides get_colors function that can be
# use to generate N random colors.
import libs.color as color

# %% [markdown]
# ### Change Current Working Directory (CWD) to: crc_data_and_metric_bundle

# %%
# print('CWD Before: ', Path.cwd())
# get current working directory
cwd = Path.cwd()
# get path to the directory where is notebook is located
notebook_dir = u.notebook_path()
# Name of the parent directory of this notebook is crc_data_and_metric_bundle_1.0
new_cwd = notebook_dir.parent
# Set new current working directory path which ends in crc_data_and_metric_bundle_1.0
os.chdir(new_cwd)
# print('CWD After: ', Path.cwd())

# %% [markdown]
# <a id="nb3-section-1"></a>
# ## 1. Load deid datasets index file (index.csv)
# index.csv file has tabular information about the deidentified (deid) datasets created using different data-deidentification libraries and algorithms.
# #### Location of index.csv: *crc_data_and_metric_bundle_1.0/index.csv*
# #### Location of this notebook: *crc_data_and_metric_bundle_1.0/notebooks/intro.ipynb*

# %%
CWD = Path.cwd()  # get current working directory path
# Create path to the index.csv file
INDEX_FILE_PATH = Path(CWD, 'index.csv')
# read index csv into idx_df variable
# idx stands for index
idx_df = pd.read_csv(INDEX_FILE_PATH, index_col=0).reset_index(drop=True)

# %% [markdown]
# Index data has a total of 298 different deid. datasets and each dataset has 23 different properties.

# %%
# See the shape of the index dataframe.
idx_df.shape
# Out:
# (458, 22)

# %%
# See five random rows of the index dataframe
idx_df.sample(5)
# Out:
#          library name    algorithm name algorithm type target dataset
# 324         subsample  subsample_40pcnt            sdc   national2019  \
# 321         subsample  subsample_40pcnt            sdc         ma2019
# 23        MostlyAI SD       MostlyAI SD     neural net         ma2019
# 294  smartnoise-synth         patectgan     neural net   national2019
# 205  smartnoise-synth               mst     stat model         ma2019
#
#      feature set name           feature space size
# 324      all-features  517839049728000000000000000  \
# 321    family-focused                  58212000000
# 23       all-features   13330105588800000000000000
# 294    family-focused                 498960000000
# 205  industry-focused                     27027000
#
#                                          features list privacy category
# 324  PUMA, AGEP, SEX, MSP, HISP, RAC1P, NOC, NPF, H...              sdc  \
# 321  PUMA, AGEP, SEX, MSP, HISP, RAC1P, NOC, NPF, O...              sdc
# 23   PUMA, AGEP, SEX, MSP, HISP, RAC1P, NOC, NPF, H...           non_dp
# 294  PUMA, AGEP, SEX, MSP, HISP, RAC1P, NOC, NPF, O...               dp
# 205  PUMA, SEX, MSP, HISP, RAC1P, OWN_RENT, INDP_CA...               dp
#
#                                   privacy label detail  epsilon  ...
# 324  A simple uniform random 40% subsample of the t...      NaN  ...  \
# 321  A simple uniform random 40% subsample of the t...      NaN  ...
# 23   The MOSTLY AI Synthetic Data Platform generate...      NaN  ...
# 294  Conditional tabular GAN using Private Aggregat...     10.0  ...
# 205  Differentially private synthetic data.  From M...      1.0  ...
#
#     variant label detail                                    research papers
# 324                  NaN  https://www.census.gov/content/dam/Census/libr...  \
# 321                  NaN  https://www.census.gov/content/dam/Census/libr...
# 23                   NaN          https://doi.org/10.48550/arXiv.2104.03007
# 294                  NaN         https://openreview.net/forum?id=S1zk9iRqF7
# 205                  NaN          https://doi.org/10.48550/arXiv.2108.04978
#
#                                              data path
# 324  deid_data/subsample_40pcnt/national/subsample_...  \
# 321  deid_data/subsample_40pcnt/ma/subsample_40pcnt...
# 23   deid_data/mostlyai_sd_MOSTLY_AI/ma/mostlyai_sd...
# 294  deid_data/smartnoise_patectgan/national/patect...
# 205  deid_data/smartnoise_mst/ma/mst_e_1_industry_m...
#
#                                            labels path
# 324  deid_data/subsample_40pcnt/national/subsample_...  \
# 321  deid_data/subsample_40pcnt/ma/subsample_40pcnt...
# 23   deid_data/mostlyai_sd_MOSTLY_AI/ma/mostlyai_sd...
# 294  deid_data/smartnoise_patectgan/national/patect...
# 205  deid_data/smartnoise_mst/ma/mst_e_1_industry_m...
#
#                                            report path       team
# 324  deid_data/subsample_40pcnt/national/r_subsampl...        CRC  \
# 321  deid_data/subsample_40pcnt/ma/r_subsample_40pc...        CRC
# 23   deid_data/mostlyai_sd_MOSTLY_AI/ma/r_mostlyai_...  MOSTLY AI
# 294  deid_data/smartnoise_patectgan/national/r_pate...        CRC
# 205  deid_data/smartnoise_mst/ma/r_mst_e_1_industry...        CRC
#
#     submission number submission timestamp  quasi identifiers subset
# 324               NaN   5/20/2023 00:00:00                       NaN  \
# 321               NaN   5/20/2023 00:00:00                       NaN
# 23                2.0   3/31/2023 11:27:22                       NaN
# 294               NaN   5/20/2023 00:00:00                       NaN
# 205               NaN   5/20/2023 00:00:00                       NaN
#
#                                  deid data id
# 324  434816825fd1677cd20097cbcb59bbe6870a7b0d
# 321  28bd61ace25aeb68591c02f6fd07abee74796e26
# 23   3847fc53a113967b7382f2be6c059b02078be32b
# 294  0a69bd584368244cdcc9d16e620d9059315a0a0c
# 205  4ab593e9d112b42cd07c30adc18eec805c1e7f54
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 1.1 Veiw available features in the index dataframe.
# List features(columns) of each deid. dataset (each row) in the index dataframe (created from index.csv).
#
# Some features inform about the method of data synthesis (features such as 'library', 'algorithm name', 'epsilon', 'variant label' etc.) and others about the location of resources (such as 'data path' path to deid dataset csv file,
# 'report path' path to sdnist evaluation report of the deid dataset file etc.)

# %%
# Iterate over the columns of index dataframe
# and print each column name
for col in idx_df.columns:
    print(col)
# Out:
# library name
# algorithm name
# algorithm type
# target dataset
# feature set name
# feature space size
# features list
# privacy category
# privacy label detail
# epsilon
# delta
# variant label
# variant label detail
# research papers
# data path
# labels path
# report path
# team
# submission number
# submission timestamp
# quasi identifiers subset
# deid data id

# %%
# Use index_feature_description function from the libs.util module.
# index_feature_description function takes just one argument which 
# should be one of the column name available in the index file. 
# Column names are printed in the last code cell for your reference.
u.index_feature_description(LIBRARY_NAME)
# Out:
# Index Column:
# -------------
# library name
#
#
# Description:
# -----------
# Software library used for this submission, or team name if a private codebase was used

# %% [markdown]
# <a id="nb3-section-2"></a>
# ## 2. Compute difference in densities percentage of each race between deid and target datasets.
# Race density is computed by finding the fraction of people of a race in a dataset. We find race density percentage for both a deid dataset and its target dataset, and then take the absolute difference of these density percentages.
# We then use the absolute difference of density percentages to create a new score called race_edit_distance_percent.

# %%
# Store path to the target dataset base directory which is 
# diverse_communities_data_excerpts.
TARGET_DATA_DIR = Path(CWD, 'diverse_communities_data_excerpts')
# Store path to all the three datasets: ma2019, tx2019, and national2019
MA_PATH = Path(TARGET_DATA_DIR, 'massachusetts', 'ma2019.csv')
TX_PATH = Path(TARGET_DATA_DIR, 'texas', 'tx2019.csv')
NAT_PATH = Path(TARGET_DATA_DIR, 'national', 'national2019.csv')


# Declare constants that we use as
# column names
DEID_COUNT = 'deid_count'
DEID_DENSITY_PERCENT = 'deid_density_percent'
TARGET_COUNT = 'target_count'
TARGET_DENSITY_PERCENT = 'target_density_percent'
DIFFERENCE = 'difference'
RACE_EDIT_DISTANCE_PERCENT = 'race_edit_distance_percent'


# Create a new zero filled column
idx_df[RACE_EDIT_DISTANCE_PERCENT] = np.zeros(idx_df.shape[0]).astype(int)

# Iterate over each row (deid dataset) in index dataframe.
for i, row in idx_df.iterrows():
    # Get path of deid. data csv file
    data_path = row[DATA_PATH]
    # Read the csv file into a pandas dataframe using data path.
    data_deid_df = pd.read_csv(data_path)
    # Cleaning step (removes extra leading column from csv).
    data_deid_df = data_deid_df.loc[:, ~data_deid_df.columns.str.startswith('Unnamed')]
    data_deid_df = data_deid_df.reset_index(drop=True)
    
    # Get path to the target dataset from which the
    # current deid dataset is created
    target_dataset_name = row[TARGET_DATASET]
    target_path = ''
    
    if target_dataset_name == MA2019:
        target_path = MA_PATH
    elif target_dataset_name == TX2019:
        target_path = TX_PATH
    elif target_dataset_name == NATIONAL2019:
        target_path = NAT_PATH
    
    data_target_df = pd.read_csv(target_path)
    
    if RAC1P not in data_deid_df.columns.tolist():
        continue

    # Get count of each race in deid dataset and save it as new dataframe
    deid_race_df = data_deid_df[RAC1P].value_counts().to_frame(DEID_COUNT)
    # Compute density percent of each race in the deid dataset
    deid_race_df[DEID_DENSITY_PERCENT] = deid_race_df[DEID_COUNT] / data_deid_df.shape[0] * 100
    
    # Get count of each race in target dataset and save it as new dataframe
    target_race_df = data_target_df[RAC1P].value_counts().to_frame(TARGET_COUNT)
    # Compute density percent of each race in the target dataset
    target_race_df[TARGET_DENSITY_PERCENT] = target_race_df[TARGET_COUNT] / data_target_df.shape[0] * 100
    
    # Move unique values of RAC1P to a new column named RAC1P and set type as
    # 'int'. We change type to 'int' because some deid dataset save RAC1P
    # value as floats.
    deid_race_df[RAC1P] = deid_race_df.index.astype(int)
    target_race_df[RAC1P] = target_race_df.index.astype(int)

    # Reset index after get race values
    deid_race_df = deid_race_df.reset_index(drop=True)
    target_race_df = target_race_df.reset_index(drop=True)
    
    # Sort deid and target dataset by race
    deid_race_df = deid_race_df.sort_values(by=RAC1P)

    target_race_df = target_race_df.sort_values(by=RAC1P)

    # Merge both dataset on RAC1P and do outer merge to take RAC1P values from
    # both deid and target dataset
    merged_df = target_race_df.merge(deid_race_df, on=RAC1P, how='outer')
    
    # Since few races can be missing in the deid dataset, those
    # will have nan values for deid_counts and deid_density_percent
    # columns after the merge operation
    merged_df = merged_df.fillna(0)
    # Get absolute difference of density percentages between target and deid dataset
    merged_df[DIFFERENCE] = abs(merged_df[DEID_DENSITY_PERCENT] - merged_df[TARGET_DENSITY_PERCENT])
        
    # Calculate edit distance between density percentages of races in 
    # target data and count of races in deid data
    edit_distance = sum(merged_df[DIFFERENCE].values)

    # Save value race values difference in
    # index dataframe.
    idx_df.loc[i, RACE_EDIT_DISTANCE_PERCENT] = round(edit_distance, 2)

# %% [markdown]
# ### 2.1 Worst performing 75 samples.

# %%
# See the random 100 records from index dataframe and
# the new column race_edit_distance which we just added to the
# index dataframe

# Set pandas display max rows option to display more
# dataframe rows in the cell output
pd.set_option('display.max_rows', 151)
# Name of the columns to display in the selected data samples
columns_to_show = [LIBRARY_NAME, ALGORITHM_NAME, ALGORITHM_TYPE, TARGET_DATASET,
                   PRIVACY_CATEGORY, EPSILON, FEATURE_SET_NAME, RACE_EDIT_DISTANCE_PERCENT]

# Sort the samples by race_edit_distance
idx_df = idx_df.sort_values(by=RACE_EDIT_DISTANCE_PERCENT, ascending=False)
# Show 75  worst performing samples in the index dataframe
idx_sample_df = idx_df[columns_to_show].sample(75)
# Show samples dataframe
idx_sample_df
# Out:
#                 library name             algorithm name  algorithm type
# 239         smartnoise-synth                        mst      stat model  \
# 445                ydata-sdk  YData Fabric Synthesizers      neural net
# 254         smartnoise-synth                   pacsynth  query matching
# 168         smartnoise-synth                        aim      stat model
# 135                      sdv                       tvae      neural net
# 197         smartnoise-synth                        mst      stat model
# 401                synthcity                  privbayes      stat model
# 235         smartnoise-synth                        mst      stat model
# 362                synthcity           bayesian_network      stat model
# 374                synthcity                    pategan      neural net
# 331                subsample           subsample_40pcnt             sdc
# 243         smartnoise-synth                       mwem  query matching
# 121                      sdv                      ctgan      neural net
# 132                      sdv                       tvae      neural net
# 179         smartnoise-synth                        aim      stat model
# 199         smartnoise-synth                        mst      stat model
# 209         smartnoise-synth                        mst      stat model
# 310         smartnoise-synth                  patectgan      neural net
# 428                ydata-sdk  YData Fabric Synthesizers      neural net
# 108                 sdcmicro                       pram             sdc
# 335                subsample            subsample_5pcnt             sdc
# 91                  sdcmicro                 kanonymity             sdc
# 438                ydata-sdk  YData Fabric Synthesizers      neural net
# 188         smartnoise-synth                        aim      stat model
# 260         smartnoise-synth                   pacsynth  query matching
# 45                 rsynthpop                       cart      stat model
# 69                 rsynthpop                        ipf  query matching
# 339                synthcity                     adsgan      neural net
# 87                  sdcmicro                 kanonymity             sdc
# 354                synthcity           bayesian_network      stat model
# 97                  sdcmicro                 kanonymity             sdc
# 357                synthcity           bayesian_network      stat model
# 205         smartnoise-synth                        mst      stat model
# 258         smartnoise-synth                   pacsynth  query matching
# 386                synthcity                    pategan      neural net
# 27               MostlyAI SD                MostlyAI SD      neural net
# 48                 rsynthpop                       cart      stat model
# 307         smartnoise-synth                  patectgan      neural net
# 161         smartnoise-synth                        aim      stat model
# 336                subsample            subsample_5pcnt             sdc
# 117                      sdv                      ctgan      neural net
# 156         smartnoise-synth                        aim      stat model
# 80                  sdcmicro                 kanonymity             sdc
# 6                 Genetic SD                 Genetic SD  query matching
# 149         smartnoise-synth                        aim      stat model
# 193         smartnoise-synth                        mst      stat model
# 176         smartnoise-synth                        aim      stat model
# 102                 sdcmicro                       pram             sdc
# 408                synthcity                       tvae      neural net
# 280         smartnoise-synth                  patectgan      neural net
# 119                      sdv                      ctgan      neural net
# 385                synthcity                    pategan      neural net
# 233         smartnoise-synth                        mst      stat model
# 219         smartnoise-synth                        mst      stat model
# 154         smartnoise-synth                        aim      stat model
# 183         smartnoise-synth                        aim      stat model
# 315                subsample            subsample_1pcnt             sdc
# 191         smartnoise-synth                        mst      stat model
# 436                ydata-sdk  YData Fabric Synthesizers      neural net
# 271         smartnoise-synth                   pacsynth  query matching
# 275         smartnoise-synth                  patectgan      neural net
# 425                ydata-sdk  YData Fabric Synthesizers      neural net
# 340                synthcity                     adsgan      neural net
# 138                      sdv                       tvae      neural net
# 147         smartnoise-synth                        aim      stat model
# 128                      sdv            gaussian-copula      stat model
# 303         smartnoise-synth                  patectgan      neural net
# 12                Genetic SD                 Genetic SD  query matching
# 215         smartnoise-synth                        mst      stat model
# 153         smartnoise-synth                        aim      stat model
# 1    Anonos Data Embassy SDK    Anonos Data Embassy SDK      neural net
# 241         smartnoise-synth                       mwem  query matching
# 61                 rsynthpop                     catall       histogram
# 446                ydata-sdk  YData Fabric Synthesizers      neural net
# 455                ydata-sdk  YData Fabric Synthesizers      neural net
#
#     target dataset privacy category  epsilon
# 239         tx2019               dp      1.0  \
# 445   national2019           non_dp      NaN
# 254         ma2019               dp     10.0
# 168   national2019               dp     10.0
# 135   national2019           non_dp      NaN
# 197         ma2019               dp     10.0
# 401         tx2019               dp      1.0
# 235         tx2019               dp      1.0
# 362         tx2019           non_dp      NaN
# 374   national2019               dp      1.0
# 331         tx2019              sdc      NaN
# 243   national2019               dp     10.0
# 121         tx2019           non_dp      NaN
# 132         ma2019           non_dp      NaN
# 179         tx2019               dp     10.0
# 199         ma2019               dp     10.0
# 209   national2019               dp      5.0
# 310         tx2019               dp     10.0
# 428         ma2019           non_dp      NaN
# 108         tx2019              sdc      NaN
# 335   national2019              sdc      NaN
# 91    national2019              sdc      NaN
# 438   national2019           non_dp      NaN
# 188         tx2019               dp     10.0
# 260   national2019               dp     10.0
# 45          ma2019           non_dp      NaN
# 69    national2019               dp      1.0
# 339         ma2019           non_dp      NaN
# 87    national2019              sdc      NaN
# 354         ma2019           non_dp      NaN
# 97          tx2019              sdc      NaN
# 357   national2019           non_dp      NaN
# 205         ma2019               dp      1.0
# 258   national2019               dp      5.0
# 386         tx2019               dp      1.0
# 27          tx2019           non_dp      NaN
# 48    national2019           non_dp      NaN
# 307         tx2019               dp      5.0
# 161   national2019               dp     10.0
# 336   national2019              sdc      NaN
# 117   national2019           non_dp      NaN
# 156         ma2019               dp      1.0
# 80          ma2019              sdc      NaN
# 6           ma2019               dp      1.0
# 149         ma2019               dp      5.0
# 193         ma2019               dp      5.0
# 176         tx2019               dp     10.0
# 102   national2019              sdc      NaN
# 408         ma2019           non_dp      NaN
# 280         ma2019               dp      5.0
# 119   national2019           non_dp      NaN
# 385         tx2019               dp     10.0
# 233         tx2019               dp     10.0
# 219   national2019               dp      5.0
# 154         ma2019               dp     10.0
# 183         tx2019               dp     10.0
# 315   national2019              sdc      NaN
# 191         ma2019               dp      5.0
# 436   national2019           non_dp      NaN
# 271         tx2019               dp      5.0
# 275         ma2019               dp      1.0
# 425         ma2019           non_dp      NaN
# 340         ma2019           non_dp      NaN
# 138   national2019           non_dp      NaN
# 147         ma2019               dp      5.0
# 128   national2019           non_dp      NaN
# 303         tx2019               dp      5.0
# 12    national2019               dp     10.0
# 215   national2019               dp      1.0
# 153         ma2019               dp      5.0
# 1     national2019           non_dp      NaN
# 241   national2019               dp     10.0
# 61    national2019               dp     10.0
# 446   national2019           non_dp      NaN
# 455         tx2019           non_dp      NaN
#
#                                 feature set name  race_edit_distance_percent
# 239                              simple-features                        3.79
# 445  demographic-focused-except-PINCP_DECILE-EDU                      199.77
# 254                             industry-focused                       13.65
# 168                               family-focused                        1.17
# 135                          demographic-focused                       13.68
# 197              demographic-focused-except-DEYE                        0.37
# 401                          demographic-focused                        0.95
# 235                     family-focused-with-DEYE                        1.57
# 362                             industry-focused                        0.86
# 374                                 all-features                       22.96
# 331                               family-focused                        1.04
# 243                    detailed-industry-focused                        0.79
# 121                                 all-features                       11.79
# 132                               family-focused                        5.89
# 179                          demographic-focused                        0.88
# 199                               family-focused                        0.29
# 209                                 all-features                        0.43
# 310                             industry-focused                        6.14
# 428                            custom-features-3                        0.00
# 108                               family-focused                        0.95
# 335                          demographic-focused                        3.14
# 91                              industry-focused                       32.01
# 438                                 all-features                        7.00
# 188                              simple-features                        0.47
# 260                               family-focused                       45.55
# 45                                family-focused                        0.71
# 69                           demographic-focused                       20.50
# 339                          demographic-focused                        9.98
# 87                                family-focused                       57.15
# 354                             industry-focused                        0.76
# 97                              industry-focused                       31.16
# 357                               family-focused                        1.02
# 205                             industry-focused                        2.44
# 258              demographic-focused-except-DEYE                       16.96
# 386                               family-focused                       26.02
# 27                                  all-features                        1.44
# 48                           demographic-focused                        1.15
# 307                               family-focused                       10.82
# 161                          demographic-focused                        0.34
# 336                               family-focused                        3.99
# 117                                 all-features                        8.19
# 156                              simple-features                        7.60
# 80                                family-focused                       18.08
# 6                                simple-features                       10.32
# 149                               family-focused                        1.23
# 193                          demographic-focused                        0.55
# 176                                 all-features                        0.69
# 102                          demographic-focused                        0.46
# 408                          demographic-focused                       10.06
# 280                               family-focused                        5.11
# 119                                 all-features                        7.24
# 385                               family-focused                        8.67
# 233                     family-focused-with-DEYE                        0.52
# 219                             industry-focused                        0.07
# 154                             industry-focused                        0.94
# 183                               family-focused                        0.50
# 315                                 all-features                        8.70
# 191                                 all-features                        0.89
# 436                                 all-features                       23.75
# 271                             industry-focused                       22.95
# 275                          demographic-focused                      136.97
# 425                                 all-features                        2.08
# 340                               family-focused                       21.14
# 138                             industry-focused                       18.10
# 147                          demographic-focused                        1.44
# 128                               family-focused                       37.67
# 303                          demographic-focused                        4.46
# 12                               simple-features                        0.61
# 215                               family-focused                        1.02
# 153                             industry-focused                        0.84
# 1                                   all-features                        1.96
# 241                           custom-features-12                        1.09
# 61                           demographic-focused                       14.33
# 446  demographic-focused-except-PINCP_DECILE-EDU                       89.23
# 455  demographic-focused-except-PINCP_DECILE-EDU                       31.16

# %%
### 2.1 Best performing 75 samples.

# %%
# See the random 100 records from index dataframe and
# the new column race_edit_distance which we just added to the
# index dataframe

# Set pandas display max rows option to display more
# dataframe rows in the cell output
pd.set_option('display.max_rows', 151)
# Name of the columns to display in the selected data samples
columns_to_show = [LIBRARY_NAME, ALGORITHM_NAME, ALGORITHM_TYPE, TARGET_DATASET,
                   PRIVACY_CATEGORY, EPSILON, FEATURE_SET_NAME, RACE_EDIT_DISTANCE_PERCENT]

# Sort the samples by race_edit_distance
idx_df = idx_df.sort_values(by=RACE_EDIT_DISTANCE_PERCENT, ascending=True)
# Show 75 best performing samples in the index dataframe
idx_sample_df = idx_df[columns_to_show].head(75)
# Show samples dataframe
idx_sample_df
# Out:
#             library name             algorithm name  algorithm type
# 449            ydata-sdk  YData Fabric Synthesizers      neural net  \
# 428            ydata-sdk  YData Fabric Synthesizers      neural net
# 429            ydata-sdk  YData Fabric Synthesizers      neural net
# 440            ydata-sdk  YData Fabric Synthesizers      neural net
# 58             rsynthpop                     catall       histogram
# 450            ydata-sdk  YData Fabric Synthesizers      neural net
# 439            ydata-sdk  YData Fabric Synthesizers      neural net
# 35   UTDallas-AIFairness                      smote       geometric
# 38   UTDallas-AIFairness                      smote       geometric
# 210     smartnoise-synth                        mst      stat model
# 32   UTDallas-AIFairness                      smote       geometric
# 219     smartnoise-synth                        mst      stat model
# 220     smartnoise-synth                        mst      stat model
# 213     smartnoise-synth                        mst      stat model
# 217     smartnoise-synth                        mst      stat model
# 216     smartnoise-synth                        mst      stat model
# 212     smartnoise-synth                        mst      stat model
# 214     smartnoise-synth                        mst      stat model
# 419               tumult                     DPHist       histogram
# 236     smartnoise-synth                        mst      stat model
# 206     smartnoise-synth                        mst      stat model
# 221     smartnoise-synth                        mst      stat model
# 199     smartnoise-synth                        mst      stat model
# 224     smartnoise-synth                        mst      stat model
# 229     smartnoise-synth                        mst      stat model
# 204     smartnoise-synth                        mst      stat model
# 161     smartnoise-synth                        aim      stat model
# 237     smartnoise-synth                        mst      stat model
# 164     smartnoise-synth                        aim      stat model
# 197     smartnoise-synth                        mst      stat model
# 322            subsample           subsample_40pcnt             sdc
# 192     smartnoise-synth                        mst      stat model
# 172     smartnoise-synth                        aim      stat model
# 209     smartnoise-synth                        mst      stat model
# 43             rsynthpop                       cart      stat model
# 102             sdcmicro                       pram             sdc
# 105             sdcmicro                       pram             sdc
# 201     smartnoise-synth                        mst      stat model
# 234     smartnoise-synth                        mst      stat model
# 188     smartnoise-synth                        aim      stat model
# 146     smartnoise-synth                        aim      stat model
# 99              sdcmicro                       pram             sdc
# 230     smartnoise-synth                        mst      stat model
# 183     smartnoise-synth                        aim      stat model
# 231     smartnoise-synth                        mst      stat model
# 218     smartnoise-synth                        mst      stat model
# 195     smartnoise-synth                        mst      stat model
# 106             sdcmicro                       pram             sdc
# 233     smartnoise-synth                        mst      stat model
# 101             sdcmicro                       pram             sdc
# 76             rsynthpop                  ipf_NonDP  query matching
# 193     smartnoise-synth                        mst      stat model
# 171     smartnoise-synth                        aim      stat model
# 198     smartnoise-synth                        mst      stat model
# 47             rsynthpop                       cart      stat model
# 160     smartnoise-synth                        aim      stat model
# 404            synthcity                  privbayes      stat model
# 150     smartnoise-synth                        aim      stat model
# 227     smartnoise-synth                        mst      stat model
# 173     smartnoise-synth                        aim      stat model
# 242     smartnoise-synth                       mwem  query matching
# 324            subsample           subsample_40pcnt             sdc
# 12            Genetic SD                 Genetic SD  query matching
# 11            Genetic SD                 Genetic SD  query matching
# 325            subsample           subsample_40pcnt             sdc
# 225     smartnoise-synth                        mst      stat model
# 394            synthcity                  privbayes      stat model
# 392            synthcity                  privbayes      stat model
# 42             rsynthpop                       cart      stat model
# 180     smartnoise-synth                        aim      stat model
# 208     smartnoise-synth                        mst      stat model
# 59             rsynthpop                     catall       histogram
# 175     smartnoise-synth                        aim      stat model
# 14            Genetic SD                 Genetic SD  query matching
# 100             sdcmicro                       pram             sdc
#
#     target dataset privacy category  epsilon
# 449         tx2019           non_dp      NaN  \
# 428         ma2019           non_dp      NaN
# 429         ma2019           non_dp      NaN
# 440   national2019           non_dp      NaN
# 58    national2019               dp    100.0
# 450         tx2019           non_dp      NaN
# 439   national2019           non_dp      NaN
# 35    national2019           non_dp      NaN
# 38          tx2019           non_dp      NaN
# 210   national2019               dp     10.0
# 32          ma2019           non_dp      NaN
# 219   national2019               dp      5.0
# 220   national2019               dp     10.0
# 213   national2019               dp      5.0
# 217   national2019               dp      5.0
# 216   national2019               dp     10.0
# 212   national2019               dp      5.0
# 214   national2019               dp      5.0
# 419   national2019               dp     10.0
# 236         tx2019               dp      5.0
# 206         ma2019               dp     10.0
# 221   national2019               dp     10.0
# 199         ma2019               dp     10.0
# 224         tx2019               dp     10.0
# 229         tx2019               dp     10.0
# 204         ma2019               dp      5.0
# 161   national2019               dp     10.0
# 237         tx2019               dp     10.0
# 164   national2019               dp     10.0
# 197         ma2019               dp     10.0
# 322         ma2019              sdc      NaN
# 192         ma2019               dp     10.0
# 172   national2019               dp     10.0
# 209   national2019               dp      5.0
# 43          ma2019           non_dp      NaN
# 102   national2019              sdc      NaN
# 105   national2019              sdc      NaN
# 201         ma2019               dp     10.0
# 234         tx2019               dp      5.0
# 188         tx2019               dp     10.0
# 146         ma2019               dp     10.0
# 99          ma2019              sdc      NaN
# 230         tx2019               dp      5.0
# 183         tx2019               dp     10.0
# 231         tx2019               dp     10.0
# 218   national2019               dp      1.0
# 195         ma2019               dp      5.0
# 106   national2019              sdc      NaN
# 233         tx2019               dp     10.0
# 101   national2019              sdc      NaN
# 76    national2019           non_dp      NaN
# 193         ma2019               dp      5.0
# 171   national2019               dp      5.0
# 198         ma2019               dp      5.0
# 47    national2019           non_dp      NaN
# 160   national2019               dp      5.0
# 404         tx2019               dp     10.0
# 150         ma2019               dp     10.0
# 227         tx2019               dp      5.0
# 173   national2019               dp     10.0
# 242   national2019               dp     10.0
# 324   national2019              sdc      NaN
# 12    national2019               dp     10.0
# 11    national2019               dp     10.0
# 325   national2019              sdc      NaN
# 225         tx2019               dp      5.0
# 394         ma2019               dp      1.0
# 392         ma2019               dp     10.0
# 42          ma2019           non_dp      NaN
# 180         tx2019               dp      5.0
# 208         ma2019               dp     10.0
# 59    national2019               dp    100.0
# 175   national2019               dp      5.0
# 14    national2019               dp     10.0
# 100         ma2019              sdc      NaN
#
#                          feature set name  race_edit_distance_percent
# 449                     custom-features-3                        0.00
# 428                     custom-features-3                        0.00
# 429                     custom-features-5                        0.00
# 440                     custom-features-5                        0.00
# 58                    demographic-focused                        0.00
# 450                     custom-features-5                        0.00
# 439                     custom-features-3                        0.00
# 35                           all-features                        0.00
# 38                           all-features                        0.00
# 210                   demographic-focused                        0.05
# 32                           all-features                        0.05
# 219                      industry-focused                        0.07
# 220                      industry-focused                        0.08
# 213       demographic-focused-except-DEYE                        0.13
# 217              family-focused-with-DEYE                        0.15
# 216                        family-focused                        0.15
# 212                   demographic-focused                        0.18
# 214                        family-focused                        0.22
# 419  demographic-focused-except-AGEP-DEYE                        0.24
# 236                      industry-focused                        0.26
# 206                      industry-focused                        0.26
# 221                       simple-features                        0.29
# 199                        family-focused                        0.29
# 224                   demographic-focused                        0.30
# 229       demographic-focused-except-DEYE                        0.30
# 204                      industry-focused                        0.31
# 161                   demographic-focused                        0.34
# 237                      industry-focused                        0.34
# 164  demographic-focused-except-AGEP-DEYE                        0.34
# 197       demographic-focused-except-DEYE                        0.37
# 322                      industry-focused                        0.40
# 192                   demographic-focused                        0.42
# 172                      industry-focused                        0.43
# 209                          all-features                        0.43
# 43                    demographic-focused                        0.45
# 102                   demographic-focused                        0.46
# 105                      industry-focused                        0.46
# 201              family-focused-with-DEYE                        0.47
# 234              family-focused-with-DEYE                        0.47
# 188                       simple-features                        0.47
# 146                   demographic-focused                        0.47
# 99                         family-focused                        0.47
# 230                        family-focused                        0.50
# 183                        family-focused                        0.50
# 231                        family-focused                        0.50
# 218                      industry-focused                        0.50
# 195       demographic-focused-except-DEYE                        0.52
# 106                      industry-focused                        0.52
# 233              family-focused-with-DEYE                        0.52
# 101                   demographic-focused                        0.52
# 76                    demographic-focused                        0.54
# 193                   demographic-focused                        0.55
# 171                      industry-focused                        0.55
# 198                        family-focused                        0.55
# 47                     custom-features-21                        0.57
# 160                          all-features                        0.57
# 404                        family-focused                        0.58
# 150                        family-focused                        0.58
# 227       demographic-focused-except-DEYE                        0.58
# 173                       simple-features                        0.59
# 242       demographic-focused-except-DEYE                        0.61
# 324                          all-features                        0.61
# 12                        simple-features                        0.61
# 11                           all-features                        0.61
# 325                   demographic-focused                        0.62
# 225                   demographic-focused                        0.63
# 394                      industry-focused                        0.63
# 392                        family-focused                        0.63
# 42                     custom-features-21                        0.63
# 180                   demographic-focused                        0.63
# 208                       simple-features                        0.65
# 59                    demographic-focused                        0.65
# 175                       simple-features                        0.67
# 14                        simple-features                        0.68
# 100                      industry-focused                        0.68
